# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/messy_HR_data.csv")
df
# Out:
#          Name     Age          Salary  Gender Department   Position  \
# 0      grace       25           50000    Male         HR    Manager
# 1      david      NaN           65000  Female    Finance   Director
# 2     hannah       35  SIXTY THOUSAND  Female      Sales   Director
# 3        eve      NaN           50000  Female         IT    Manager
# 4      grace      NaN            NAN   Female    Finance    Manager
# ..        ...     ...             ...     ...        ...        ...
# 995     jack       50           65000  Female         HR    Manager
# 996     jack   thirty           50000    Male    Finance    Analyst
# 997   hannah   thirty           70000    Male         IT  Assistant
# 998      bob       25           65000   Other  Marketing    Manager
# 999      ivy   thirty  SIXTY THOUSAND    Male    Finance    Manager
#
#       Joining Date Performance Score              Email  Phone Number
# 0    April 5, 2018                 D  email@example.com           NaN
# ...

# %%
df.reset_index(inplace=True)

# %%
rows ,colums = df.shape #/It is a tuple

# %%
df.head()
# Out:
#    index      Name  Age          Salary  Gender Department  Position  \
# 0      0    grace    25           50000    Male         HR   Manager
# 1      1    david   NaN           65000  Female    Finance  Director
# 2      2   hannah    35  SIXTY THOUSAND  Female      Sales  Director
# 3      3      eve   NaN           50000  Female         IT   Manager
# 4      4    grace   NaN            NAN   Female    Finance   Manager
#
#     Joining Date Performance Score              Email  Phone Number
# 0  April 5, 2018                 D  email@example.com           NaN
# 1     2020/02/20                 F    user@domain.com  123-456-7890
# 2     01/15/2020                 C  email@example.com  098-765-4321
# 3  April 5, 2018                 A   name@company.org
# 4     01/15/2020                 F   name@company.org  098-765-4321

# %%
df.head()
# Out:
#    index      Name  Age          Salary  Gender Department  Position  \
# 0      0    grace    25           50000    Male         HR   Manager
# 1      1    david   NaN           65000  Female    Finance  Director
# 2      2   hannah    35  SIXTY THOUSAND  Female      Sales  Director
# 3      3      eve   NaN           50000  Female         IT   Manager
# 4      4    grace   NaN            NAN   Female    Finance   Manager
#
#     Joining Date Performance Score              Email  Phone Number
# 0  April 5, 2018                 D  email@example.com           NaN
# 1     2020/02/20                 F    user@domain.com  123-456-7890
# 2     01/15/2020                 C  email@example.com  098-765-4321
# 3  April 5, 2018                 A   name@company.org
# 4     01/15/2020                 F   name@company.org  098-765-4321

# %%
df.Salary[:]
# Out:
# 0               50000
# 1               65000
# 2      SIXTY THOUSAND
# 3               50000
# 4                NAN
#             ...
# 995             65000
# 996             50000
# 997             70000
# 998             65000
# 999    SIXTY THOUSAND
# Name: Salary, Length: 1000, dtype: str

# %%
df['Salary'] = df['Salary'].replace('SIXTY THOUSAND',60000)

# %%
print(df['Salary'].unique())
# Out:
# ['50000' '65000' 60000 ' NAN ' '70000' '55000']

# %%
df['Salary'] = df['Salary'].replace(' NAN ',0)

# %%
df['Salary'] = pd.to_numeric(df['Salary'])

# %%
print(df['Salary'].unique())
# Out:
# [50000 65000 60000     0 70000 55000]

# %%
df.Salary
# Out:
# 0      50000
# 1      65000
# 2      60000
# 3      50000
# 4          0
#        ...
# 995    65000
# 996    50000
# 997    70000
# 998    65000
# 999    60000
# Name: Salary, Length: 1000, dtype: int64

# %%
df.Salary.mean()
# Out:
# np.float64(50160.0)

# %%
df.Salary.unique()
# Out:
# array([50000, 65000, 60000,     0, 70000, 55000])

# %%
df['Salary']=df['Salary'].replace(0,50140)

# %%
df.Age.unique()
# Out:
# <StringArray>
# ['25', nan, '35', '40', 'thirty', '50']
# Length: 6, dtype: str

# %%
df['Age'] = df.Age.replace('thirty',30)

# %%
df['Age'] = pd.to_numeric(df['Age'])

# %%
df.Age.mean()
# Out:
# np.float64(35.8026159334126)

# %%
df.Age.unique()
# Out:
# array([25., nan, 35., 40., 30., 50.])

# %%
df['Age'] = df['Age'].fillna(35)
df.Age
# Out:
# 0      25.0
# 1      35.0
# 2      35.0
# 3      35.0
# 4      35.0
#        ...
# 995    50.0
# 996    30.0
# 997    30.0
# 998    25.0
# 999    30.0
# Name: Age, Length: 1000, dtype: float64

# %%
df.Email.unique()
# Out:
# <StringArray>
# ['email@example.com', 'user@domain.com', 'name@company.org', nan]
# Length: 4, dtype: str

# %%
df['Email'] = df['Email'].fillna('user@domain,com')

# %%
df['Phone Number'].unique()
# Out:
# <StringArray>
# [nan, '123-456-7890', '098-765-4321', ' ', '555-555-5555']
# Length: 5, dtype: str

# %%
df['Phone Number'] = df['Phone Number'].fillna(123-456-7777)

# %%
df['Phone Number'] = df['Phone Number'].fillna(101-111-2345)

# %%
df
# Out:
#      index      Name   Age  Salary  Gender Department   Position  \
# 0        0    grace   25.0   50000    Male         HR    Manager
# 1        1    david   35.0   65000  Female    Finance   Director
# 2        2   hannah   35.0   60000  Female      Sales   Director
# 3        3      eve   35.0   50000  Female         IT    Manager
# 4        4    grace   35.0   50140  Female    Finance    Manager
# ..     ...       ...   ...     ...     ...        ...        ...
# 995    995     jack   50.0   65000  Female         HR    Manager
# 996    996     jack   30.0   50000    Male    Finance    Analyst
# 997    997   hannah   30.0   70000    Male         IT  Assistant
# 998    998      bob   25.0   65000   Other  Marketing    Manager
# 999    999      ivy   30.0   60000    Male    Finance    Manager
#
#       Joining Date Performance Score              Email  Phone Number
# 0    April 5, 2018                 D  email@example.com         -8110
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\swast\PycharmProjects\JupyterProjectforPandas,numpyetc
